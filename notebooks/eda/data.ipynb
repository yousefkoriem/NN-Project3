# %%
import os
os.chdir('/home/bluefox/NN/NN-Project3')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import keras
from keras.datasets import cifar10
# Out:
# 2026-05-16 21:53:23.948956: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-16 21:53:24.065563: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-16 21:53:25.677753: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
(x_train, y_train), (x_test,y_test) = cifar10.load_data()

# %%
x_train.shape, y_train.shape, x_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (50000, 1))

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
x_train[0]
# Out:
# array([[[0.23137255, 0.24313725, 0.24705882],
#         [0.16862745, 0.18039216, 0.17647059],
#         [0.19607843, 0.18823529, 0.16862745],
#         ...,
#         [0.61960784, 0.51764706, 0.42352941],
#         [0.59607843, 0.49019608, 0.4       ],
#         [0.58039216, 0.48627451, 0.40392157]],
#
#        [[0.0627451 , 0.07843137, 0.07843137],
#         [0.        , 0.        , 0.        ],
#         [0.07058824, 0.03137255, 0.        ],
#         ...,
#         [0.48235294, 0.34509804, 0.21568627],
#         [0.46666667, 0.3254902 , 0.19607843],
#         [0.47843137, 0.34117647, 0.22352941]],
#
#        [[0.09803922, 0.09411765, 0.08235294],
#         [0.0627451 , 0.02745098, 0.        ],
#         [0.19215686, 0.10588235, 0.03137255],
#         ...,
#         [0.4627451 , 0.32941176, 0.19607843],
#         [0.47058824, 0.32941176, 0.19607843],
#         [0.42745098, 0.28627451, 0.16470588]],
#
#        ...,
#
#        [[0.81568627, 0.66666667, 0.37647059],
# ...

# %%
y_train = keras.utils.to_categorical(y_train,num_classes=10)
y_test = keras.utils.to_categorical(y_test,num_classes=10)

# %%
x_train.shape, y_train.shape, x_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 10), (10000, 32, 32, 3), (50000, 10))

# %%
import pickle

# %%
pickle.dump(obj=(x_train,y_train),file=open('data/processed/train_data.pkl', 'wb'))
pickle.dump(obj=(x_test,y_test),file=open('data/processed/test_data.pkl', 'wb'))

# %%
np.savez("data/processed/cifar10_data.npz", x_train=x_train, y_train=y_train, x_test=x_test, y_test=y_test)

# %%
import joblib
joblib.dump((x_train,y_train), "data/processed/train_data.h5")
joblib.dump((x_test,y_test), "data/processed/test_data.h5")
# Out:
# ['data/processed/test_data.h5']
