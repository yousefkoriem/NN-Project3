# %%
import os
os.chdir('/home/bluefox/NN/NN-Project3')

# %%
# !python scripts/data.py
# Out:
# 2026-05-16 12:33:30.206500: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-16 12:33:30.207986: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-16 12:33:30.364759: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-16 12:33:31.482616: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-16 12:33:31.483082: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# /home/bluefox/NN/NN-Project3

# %%
import pickle
import pandas as pd
import numpy as np
import joblib
import keras
import tensorflow as tf
# Out:
# 2026-05-16 12:31:02.131888: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-16 12:31:02.132381: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-16 12:31:02.181004: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-16 12:31:03.775641: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-16 12:31:03.775981: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
(x_train,y_train) = pickle.load(open('data/processed/train_data.pkl','rb'))
(x_test,y_test) = pickle.load(open('data/processed/test_data.pkl','rb'))

# %%
from keras import callbacks, layers, models, regularizers, optimizers, callbacks,losses,metrics

# %%
checkpoint = callbacks.ModelCheckpoint(
    filepath='models/architecture/best_cifar10_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# %%
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

# %%
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

# %%
model = models.load_model('models/architecture/untrained_cifar10_model.keras')

# %%
history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    callbacks=[checkpoint, early_stopping, reduce_lr]
)

# %%
history_df = pd.DataFrame(history.history)
history_df.to_csv('results/tables/training_history.csv', index=False)

# %%
score = model.evaluate(x_test, y_test)
score_df = pd.DataFrame({'loss': [score[0]], 'accuracy': [score[1]],'f1_score': [score[2]]})
score_df.to_csv('results/tables/test_score.csv', index=False)

# %%
model.save('models/architecture/final_cifar10_model.keras')
